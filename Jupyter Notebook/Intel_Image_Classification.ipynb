# %% [markdown]
# # Intel Image Classification

# %% [markdown]
# In this project, we will be working on Intel images i.e. images of buildings, forest, street, etc. We will built a convolutional neural network and train it on this images. This is a multi class classification problem and we will use Keras.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive".
# !ls "/content/drive/MyDrive/Intel Image Dataset"
# Out:
# buildings  forest  glacier  mountain  sea  street

# %%
# Important imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from PIL import Image
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, LeakyReLU
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Listing directory
# !ls "/content/drive/My Drive/Intel Image Dataset/"
# Out:
# buildings  forest  glacier  mountain  sea  street

# %%
# Plotting 25 images to check dataset
plt.figure(figsize=(11,11))
path = "/content/drive/My Drive/Intel Image Dataset/mountain"
for i in range(1,26):
    plt.subplot(5,5,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.title('mountain')
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the mountain images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
# Setting root directory path and creating empty list
dir = "/content/drive/My Drive/Intel Image Dataset/"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Setting the root directory for the dataset and storing all the folders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = Image.open(image_path)
    image = image.resize((150,150)) # All images does not have same dimension
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Next we need to resize images as some of the images don't have same dimensions. So, we will read and resize all the images. Then we will convert it into array and appending the list created above with the image and its label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# glacier      553
# mountain     525
# street       511
# sea          510
# forest       474
# buildings    437
# dtype: int64

# %% [markdown]
# Checking for images per class.

# %%
# Checking count of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Storing the number of classes which will be used further in model architecture.

# %%
# Checking x data shape
np.array(image_list).shape
# Out:
# (3010, 150, 150, 3)

# %% [markdown]
# Check the shape of the x data for input layer of model architecture.

# %%
# Checking y data shape
label_list = np.array(label_list)
label_list.shape
# Out:
# (3010,)

# %% [markdown]
# Checking the number of labels in y data which should be equal to total number of images.

# %%
# Splitting dataset into test and train
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will split our dataset into testing and training using train_test_split() from sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 150,150,3)
x_test = x_test.reshape( -1, 150,150,3)

# %% [markdown]
# Next we will normalize the images by dividing them with 255 and we will also reshape x_train and x_test data.

# %%
# Binarizing labels
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']

# %% [markdown]
# Here we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Creating model architecture
model = Sequential([
        Conv2D(16, kernel_size = (3,3), input_shape = (150,150,3)),
        BatchNormalization(),
        LeakyReLU(),
          
        Conv2D(32, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        MaxPooling2D(5,5),
        
        Conv2D(64, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        
        Conv2D(128, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        MaxPooling2D(5,5),

        Flatten(),
    
        Dense(64),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(),
        
        Dense(32),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(),
    
        Dense(16),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(1),
    
        Dense(6, activation = 'softmax')    
        ])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  batch_normalization (BatchN  (None, 148, 148, 16)     64
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 148, 148, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 32)      4640
#
#  batch_normalization_1 (Batc  (None, 146, 146, 32)     128
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 146, 146, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 29, 29, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 27, 27, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 27, 27, 64)       256
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 27, 27, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 25, 25, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 25, 25, 128)      512
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 64)                204864
#
#  dropout (Dropout)           (None, 64)                0
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  batch_normalization_5 (Batc  (None, 32)               128
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  batch_normalization_6 (Batc  (None, 16)               64
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 16)                0
#
#  dense_3 (Dense)             (None, 6)                 102
#
# =================================================================
# Total params: 306,422
# Trainable params: 305,718
# Non-trainable params: 704
# _________________________________________________________________

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %% [markdown]
# For compiling the model we need to pass 3 parameters namely loss, optimizer and metrics. Here we will use loss as categorical_crossentropy, optimizer as Adam and metrics as accuracy.

# %%
# Training the model
epochs = 100
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/100
# 16/16 [==============================] - 17s 200ms/step - loss: 1.5946 - accuracy: 0.3967 - val_loss: 1.7410 - val_accuracy: 0.2531
# Epoch 2/100
# 16/16 [==============================] - 2s 128ms/step - loss: 1.2517 - accuracy: 0.5452 - val_loss: 1.7669 - val_accuracy: 0.2739
# Epoch 3/100
# 16/16 [==============================] - 2s 128ms/step - loss: 1.1060 - accuracy: 0.6002 - val_loss: 1.7889 - val_accuracy: 0.3133
# Epoch 4/100
# 16/16 [==============================] - 2s 129ms/step - loss: 1.0224 - accuracy: 0.6578 - val_loss: 1.7949 - val_accuracy: 0.3050
# Epoch 5/100
# 16/16 [==============================] - 2s 137ms/step - loss: 0.9452 - accuracy: 0.6807 - val_loss: 1.8104 - val_accuracy: 0.2116
# Epoch 6/100
# 16/16 [==============================] - 2s 127ms/step - loss: 0.9165 - accuracy: 0.7004 - val_loss: 1.8569 - val_accuracy: 0.1784
# Epoch 7/100
# 16/16 [==============================] - 2s 129ms/step - loss: 0.8541 - accuracy: 0.7186 - val_loss: 1.8530 - val_accuracy: 0.2780
# Epoch 8/100
# 16/16 [==============================] - 2s 129ms/step - loss: 0.8899 - accuracy: 0.6994 - val_loss: 1.9806 - val_accuracy: 0.2635
# Epoch 9/100
# 16/16 [==============================] - 2s 129ms/step - loss: 0.8963 - accuracy: 0.6983 - val_loss: 1.9883 - val_accuracy: 0.2822
# Epoch 10/100
# 16/16 [==============================] - 2s 129ms/step - loss: 0.7993 - accuracy: 0.7362 - val_loss: 1.9044 - val_accuracy: 0.2842
# Epoch 11/100
# 16/16 [==============================] - 2s 138ms/step - loss: 0.7593 - accuracy: 0.7492 - val_loss: 1.8965 - val_accuracy: 0.2697
# Epoch 12/100
# 16/16 [==============================] - 2s 128ms/step - loss: 0.6925 - accuracy: 0.7767 - val_loss: 1.8949 - val_accuracy: 0.2469
# Epoch 13/100
# 16/16 [==============================] - 2s 130ms/step - loss: 0.6910 - accuracy: 0.7773 - val_loss: 1.9117 - val_accuracy: 0.2552
# Epoch 14/100
# 16/16 [==============================] - 2s 129ms/step - loss: 0.7176 - accuracy: 0.7643 - val_loss: 1.9440 - val_accuracy: 0.3174
# Epoch 15/100
# 16/16 [==============================] - 2s 130ms/step - loss: 0.6990 - accuracy: 0.7840 - val_loss: 2.0465 - val_accuracy: 0.2739
# Epoch 16/100
# 16/16 [==============================] - 2s 129ms/step - loss: 0.6400 - accuracy: 0.8048 - val_loss: 1.8038 - val_accuracy: 0.3755
# Epoch 17/100
# 16/16 [==============================] - 2s 129ms/step - loss: 0.6200 - accuracy: 0.8074 - val_loss: 1.6549 - val_accuracy: 0.3838
# Epoch 18/100
# 16/16 [==============================] - 2s 130ms/step - loss: 0.5940 - accuracy: 0.8011 - val_loss: 1.5694 - val_accuracy: 0.4481
# Epoch 19/100
# 16/16 [==============================] - 2s 129ms/step - loss: 0.5589 - accuracy: 0.8281 - val_loss: 1.5947 - val_accuracy: 0.4253
# Epoch 20/100
# 16/16 [==============================] - 2s 130ms/step - loss: 0.5261 - accuracy: 0.8479 - val_loss: 1.5158 - val_accuracy: 0.4730
# Epoch 21/100
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5576 - accuracy: 0.8297 - val_loss: 1.2993 - val_accuracy: 0.4959
# Epoch 22/100
# 16/16 [==============================] - 2s 130ms/step - loss: 0.4980 - accuracy: 0.8609 - val_loss: 1.1244 - val_accuracy: 0.5643
# Epoch 23/100
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4887 - accuracy: 0.8655 - val_loss: 0.9932 - val_accuracy: 0.6784
# Epoch 24/100
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4617 - accuracy: 0.8712 - val_loss: 1.0730 - val_accuracy: 0.5830
# Epoch 25/100
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4852 - accuracy: 0.8671 - val_loss: 1.1998 - val_accuracy: 0.5145
# Epoch 26/100
# 16/16 [==============================] - 2s 131ms/step - loss: 0.4955 - accuracy: 0.8525 - val_loss: 1.0695 - val_accuracy: 0.5602
# Epoch 27/100
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5017 - accuracy: 0.8593 - val_loss: 1.1072 - val_accuracy: 0.5788
# Epoch 28/100
# 16/16 [==============================] - 2s 131ms/step - loss: 0.5421 - accuracy: 0.8219 - val_loss: 1.4330 - val_accuracy: 0.4751
# Epoch 29/100
# 16/16 [==============================] - 2s 140ms/step - loss: 0.5841 - accuracy: 0.8094 - val_loss: 0.9491 - val_accuracy: 0.6369
# Epoch 30/100
# 16/16 [==============================] - 2s 140ms/step - loss: 0.4673 - accuracy: 0.8593 - val_loss: 0.7856 - val_accuracy: 0.7324
# Epoch 31/100
# 16/16 [==============================] - 2s 135ms/step - loss: 0.5161 - accuracy: 0.8292 - val_loss: 0.8990 - val_accuracy: 0.6680
# Epoch 32/100
# 16/16 [==============================] - 2s 138ms/step - loss: 0.4159 - accuracy: 0.8801 - val_loss: 0.7506 - val_accuracy: 0.7116
# Epoch 33/100
# 16/16 [==============================] - 2s 132ms/step - loss: 0.4206 - accuracy: 0.8744 - val_loss: 0.8580 - val_accuracy: 0.6763
# Epoch 34/100
# 16/16 [==============================] - 2s 132ms/step - loss: 0.4046 - accuracy: 0.8863 - val_loss: 0.6444 - val_accuracy: 0.7822
# Epoch 35/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3594 - accuracy: 0.9055 - val_loss: 0.7703 - val_accuracy: 0.7303
# Epoch 36/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3348 - accuracy: 0.9138 - val_loss: 0.8042 - val_accuracy: 0.7220
# Epoch 37/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.3327 - accuracy: 0.9169 - val_loss: 0.7111 - val_accuracy: 0.7469
# Epoch 38/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3404 - accuracy: 0.9164 - val_loss: 0.6888 - val_accuracy: 0.7614
# Epoch 39/100
# 16/16 [==============================] - 2s 135ms/step - loss: 0.3863 - accuracy: 0.8941 - val_loss: 0.7279 - val_accuracy: 0.7365
# Epoch 40/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3703 - accuracy: 0.8977 - val_loss: 0.9740 - val_accuracy: 0.6494
# Epoch 41/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.3746 - accuracy: 0.8920 - val_loss: 1.1700 - val_accuracy: 0.6100
# Epoch 42/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3229 - accuracy: 0.9169 - val_loss: 0.8968 - val_accuracy: 0.6971
# Epoch 43/100
# 16/16 [==============================] - 2s 135ms/step - loss: 0.3392 - accuracy: 0.9081 - val_loss: 1.4334 - val_accuracy: 0.5643
# Epoch 44/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.3476 - accuracy: 0.9019 - val_loss: 1.2246 - val_accuracy: 0.5913
# Epoch 45/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.3196 - accuracy: 0.9138 - val_loss: 0.9114 - val_accuracy: 0.7116
# Epoch 46/100
# 16/16 [==============================] - 2s 135ms/step - loss: 0.2879 - accuracy: 0.9299 - val_loss: 0.6246 - val_accuracy: 0.7863
# Epoch 47/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.2483 - accuracy: 0.9403 - val_loss: 0.6917 - val_accuracy: 0.7427
# Epoch 48/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.2648 - accuracy: 0.9346 - val_loss: 0.9520 - val_accuracy: 0.6826
# Epoch 49/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3286 - accuracy: 0.9045 - val_loss: 0.9629 - val_accuracy: 0.6805
# Epoch 50/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3002 - accuracy: 0.9237 - val_loss: 0.7837 - val_accuracy: 0.7033
# Epoch 51/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.3289 - accuracy: 0.9039 - val_loss: 1.3503 - val_accuracy: 0.5685
# Epoch 52/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2799 - accuracy: 0.9278 - val_loss: 0.7953 - val_accuracy: 0.6992
# Epoch 53/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2761 - accuracy: 0.9263 - val_loss: 0.7870 - val_accuracy: 0.6929
# Epoch 54/100
# 16/16 [==============================] - 2s 132ms/step - loss: 0.2364 - accuracy: 0.9455 - val_loss: 0.6557 - val_accuracy: 0.7759
# Epoch 55/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2006 - accuracy: 0.9538 - val_loss: 0.7722 - val_accuracy: 0.7241
# Epoch 56/100
# 16/16 [==============================] - 2s 132ms/step - loss: 0.2657 - accuracy: 0.9325 - val_loss: 1.1165 - val_accuracy: 0.6411
# Epoch 57/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2313 - accuracy: 0.9403 - val_loss: 0.9021 - val_accuracy: 0.6805
# Epoch 58/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3016 - accuracy: 0.9081 - val_loss: 1.0383 - val_accuracy: 0.6556
# Epoch 59/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2398 - accuracy: 0.9393 - val_loss: 0.7434 - val_accuracy: 0.7573
# Epoch 60/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3052 - accuracy: 0.9045 - val_loss: 1.1727 - val_accuracy: 0.6017
# Epoch 61/100
# 16/16 [==============================] - 2s 132ms/step - loss: 0.2473 - accuracy: 0.9341 - val_loss: 1.0827 - val_accuracy: 0.6390
# Epoch 62/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2641 - accuracy: 0.9268 - val_loss: 0.9363 - val_accuracy: 0.6867
# Epoch 63/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2348 - accuracy: 0.9382 - val_loss: 0.8321 - val_accuracy: 0.7324
# Epoch 64/100
# 16/16 [==============================] - 2s 132ms/step - loss: 0.1827 - accuracy: 0.9621 - val_loss: 0.7168 - val_accuracy: 0.7510
# Epoch 65/100
# 16/16 [==============================] - 2s 141ms/step - loss: 0.1519 - accuracy: 0.9772 - val_loss: 0.8732 - val_accuracy: 0.7054
# Epoch 66/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.1518 - accuracy: 0.9772 - val_loss: 0.5917 - val_accuracy: 0.7863
# Epoch 67/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2051 - accuracy: 0.9512 - val_loss: 0.6854 - val_accuracy: 0.7531
# Epoch 68/100
# 16/16 [==============================] - 2s 132ms/step - loss: 0.1550 - accuracy: 0.9688 - val_loss: 0.7965 - val_accuracy: 0.7386
# Epoch 69/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3200 - accuracy: 0.9029 - val_loss: 1.4606 - val_accuracy: 0.6224
# Epoch 70/100
# 16/16 [==============================] - 2s 132ms/step - loss: 0.2556 - accuracy: 0.9283 - val_loss: 1.0670 - val_accuracy: 0.6743
# Epoch 71/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.1922 - accuracy: 0.9548 - val_loss: 0.8242 - val_accuracy: 0.7303
# Epoch 72/100
# 16/16 [==============================] - 2s 135ms/step - loss: 0.2230 - accuracy: 0.9408 - val_loss: 1.1142 - val_accuracy: 0.6784
# Epoch 73/100
# 16/16 [==============================] - 2s 137ms/step - loss: 0.2228 - accuracy: 0.9372 - val_loss: 1.1122 - val_accuracy: 0.6286
# Epoch 74/100
# 16/16 [==============================] - 2s 132ms/step - loss: 0.2710 - accuracy: 0.9169 - val_loss: 0.7258 - val_accuracy: 0.7552
# Epoch 75/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2171 - accuracy: 0.9372 - val_loss: 0.6486 - val_accuracy: 0.7863
# Epoch 76/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.3102 - accuracy: 0.9071 - val_loss: 2.7361 - val_accuracy: 0.3942
# Epoch 77/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3094 - accuracy: 0.9019 - val_loss: 2.2334 - val_accuracy: 0.3880
# Epoch 78/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.2301 - accuracy: 0.9356 - val_loss: 1.3313 - val_accuracy: 0.5643
# Epoch 79/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2669 - accuracy: 0.9216 - val_loss: 0.7768 - val_accuracy: 0.7407
# Epoch 80/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2234 - accuracy: 0.9429 - val_loss: 0.8081 - val_accuracy: 0.6909
# Epoch 81/100
# 16/16 [==============================] - 2s 142ms/step - loss: 0.2038 - accuracy: 0.9486 - val_loss: 0.7831 - val_accuracy: 0.7199
# Epoch 82/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2700 - accuracy: 0.9159 - val_loss: 0.7838 - val_accuracy: 0.7324
# Epoch 83/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3925 - accuracy: 0.8707 - val_loss: 0.7298 - val_accuracy: 0.7490
# Epoch 84/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3391 - accuracy: 0.8962 - val_loss: 1.0109 - val_accuracy: 0.6909
# Epoch 85/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2459 - accuracy: 0.9237 - val_loss: 2.9804 - val_accuracy: 0.4419
# Epoch 86/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3641 - accuracy: 0.8806 - val_loss: 1.8546 - val_accuracy: 0.4793
# Epoch 87/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.3209 - accuracy: 0.9003 - val_loss: 0.6567 - val_accuracy: 0.7573
# Epoch 88/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.2639 - accuracy: 0.9128 - val_loss: 0.7593 - val_accuracy: 0.7407
# Epoch 89/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2091 - accuracy: 0.9434 - val_loss: 0.6547 - val_accuracy: 0.7718
# Epoch 90/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.1819 - accuracy: 0.9444 - val_loss: 0.7562 - val_accuracy: 0.7241
# Epoch 91/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2795 - accuracy: 0.9174 - val_loss: 0.6239 - val_accuracy: 0.7676
# Epoch 92/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2113 - accuracy: 0.9418 - val_loss: 0.6691 - val_accuracy: 0.7635
# Epoch 93/100
# 16/16 [==============================] - 2s 143ms/step - loss: 0.1896 - accuracy: 0.9450 - val_loss: 0.7458 - val_accuracy: 0.7075
# Epoch 94/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.1477 - accuracy: 0.9642 - val_loss: 0.7236 - val_accuracy: 0.7365
# Epoch 95/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.1445 - accuracy: 0.9631 - val_loss: 0.6175 - val_accuracy: 0.7697
# Epoch 96/100
# 16/16 [==============================] - 2s 134ms/step - loss: 0.1645 - accuracy: 0.9574 - val_loss: 0.7218 - val_accuracy: 0.7531
# Epoch 97/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.1390 - accuracy: 0.9678 - val_loss: 1.0524 - val_accuracy: 0.6701
# Epoch 98/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2156 - accuracy: 0.9387 - val_loss: 1.0172 - val_accuracy: 0.7054
# Epoch 99/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.1584 - accuracy: 0.9611 - val_loss: 1.1059 - val_accuracy: 0.6784
# Epoch 100/100
# 16/16 [==============================] - 2s 133ms/step - loss: 0.2149 - accuracy: 0.9465 - val_loss: 0.8828 - val_accuracy: 0.7095

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 70 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("/content/drive/My Drive/intel_image.h5")

# %% [markdown]
# We will save the model using model.save() to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the loss of the model for the training history.

# %%
# Calculating test accuracy 
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 19/19 [==============================] - 1s 23ms/step - loss: 0.8485 - accuracy: 0.7126
# Test Accuracy: 71.26246094703674

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing model predictions
y_pred = model.predict(x_test)

# %% [markdown]
# Generating predictions for test data and storing them into y_pred.

# %%
# Plotting image to compare
img = array_to_img(x_test[1])
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FEFFA10E550>

# %% [markdown]
# Visualizing an image to be predicted in further steps.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[1])])
print("Predicted : ",labels[np.argmax(y_pred[1])])
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']
# Originally :  forest
# Predicted :  forest
